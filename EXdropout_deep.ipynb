# %%
import numpy as np
import seaborn as sns
from sklearn.model_selection import StratifiedKFold, train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %run deepCNN.ipynb
# %run train_model.ipynb
# %run data_handler.ipynb


kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=None)
device = torch.device('cuda:4' if torch.cuda.is_available() else 'cpu')

#This is my 5-fold validation loop :D
def cross_validation_loop(LR = 0.001, epochs = 50, batch_size = 4, dropout = 0.5):
    filename = "results/dropout_deep.txt"

    fil = open(filename, "a")
    fil.write("Experiment done on model {0}. \n Learning rate: {1} \n Optimizer: {2} \n Loss function: {3} \n Epochs: {6}, Batch size: {7},  Dropout:{8} \n Experiments run on {4} interval with frequency {5} Hz on the data."
    .format("deepCNN", LR, "Adam", "NLLLoss", "full", 254, epochs, batch_size, dropout))
    fil.close()

    saved_models = []

    for subject_nr in range(1,11): # TODO: change this back
        subject_models = []
        print("Loading subject ", subject_nr)
        data, description = load_subject(subject_nr)
        data, description = get_innerspeech(data, description)
        # data_interval = extract_action_interval(data, hz = 254)
        labels = extract_labels(description)

        train_accuracies = []
        val_accuracies = []
        test_accuracies = []

        i = 0
        for train_index, test_index in kf.split(data, labels, labels):
            print("### Fold {0} ###".format(i))

            # New model
            model = DeepCNN(hz = 254, interval = "full", dropout=dropout).float().to(device)
            loss_func = nn.NLLLoss()
            op = optim.Adam(params = model.parameters(), lr = LR)

            # Choose train+val data/labels
            train_da=data[train_index]
            train_la=labels[train_index]
            # Choose test data/labels
            test_data=data[test_index]
            test_labels=labels[test_index]

            # Split train into train and val
            train_data, val_data, train_labels, val_labels = train_test_split(train_da, train_la, test_size = 0.25, random_state = None, shuffle = True, stratify = train_la)
            train_data, val_data, test_data, train_labels, val_labels, test_labels = to_device(train_data, val_data, test_data, train_labels, val_labels, test_labels, device)
            # Train loop
            train_model(model, train_data = train_data, train_labels = train_labels, val_data = val_data, val_labels = val_labels, 
                        epochs = epochs, batch_size = batch_size, loss_func = loss_func, optimizer = op)
            # Save model
            subject_models.append(model)
            i += 1
            # Save accuracies
            train_accuracies.append(accuracy_check(model, train_data, train_labels))
            val_accuracies.append(accuracy_check(model, val_data, val_labels))
            test_accuracies.append(accuracy_check(model, test_data, test_labels))
            cf = get_conf_matrix(model, test_data, test_labels)
            plt.show(sns.heatmap(cf, annot=True))
        
        saved_models.append(subject_models)
        # Write results for subject to file
        fil = open(filename, "a")
        fil.write("\n\nResults for subject {0}.\n".format(subject_nr))
        fil.write("Train accuracies from 5 folds:\n")
        for acc in train_accuracies:
            fil.write("{0}, ".format(acc))
        fil.write("\n")
        fil.write("Validation accuracies from 5 folds:\n")
        for acc in val_accuracies:
            fil.write("{0}, ".format(acc))
        fil.write("\n")
        fil.write("Test accuracies from 5 folds:\n")
        for acc in test_accuracies:
            fil.write("{0}, ".format(acc))
        fil.write("\n")

        fil.write("Avg train acc: {0}, Avg validation acc: {1}, Avg test acc: {2}, ".format(sum(train_accuracies)/5, sum(val_accuracies)/5, sum(test_accuracies)/5))
        fil.write("\n\n#####################################\n\n")
        fil.close()
    return saved_models

# %%
print("######## Dropout: 0.01")
saved_models1 = cross_validation_loop(dropout=0.01)
# Out:
# ######## Dropout: 0.01
# Loading subject  1
# ### Fold 0 ###
# Best model found on epoch:  5
# ### Fold 1 ###
# Best model found on epoch:  31
# ### Fold 2 ###
# Best model found on epoch:  5
# ### Fold 3 ###
# Best model found on epoch:  5
# ### Fold 4 ###
# Best model found on epoch:  49
# Loading subject  2
# ### Fold 0 ###
# Best model found on epoch:  6
# ### Fold 1 ###
# Best model found on epoch:  6
# ### Fold 2 ###
# Best model found on epoch:  49
# ### Fold 3 ###
# Best model found on epoch:  5
# ### Fold 4 ###
# Best model found on epoch:  21
# Loading subject  3
# ### Fold 0 ###
# Best model found on epoch:  11
# ### Fold 1 ###
# Best model found on epoch:  5
# ### Fold 2 ###
# Best model found on epoch:  49
# ### Fold 3 ###
# Best model found on epoch:  6
# ### Fold 4 ###
# Best model found on epoch:  49
# Loading subject  4
# ### Fold 0 ###
# Best model found on epoch:  7
# ### Fold 1 ###
# Best model found on epoch:  7
# ### Fold 2 ###
# Best model found on epoch:  22
# ### Fold 3 ###
# Best model found on epoch:  6
# ### Fold 4 ###
# Best model found on epoch:  8
# Loading subject  5
# ### Fold 0 ###
# Best model found on epoch:  6
# ### Fold 1 ###
# Best model found on epoch:  35
# ### Fold 2 ###
# Best model found on epoch:  49
# ### Fold 3 ###
# Best model found on epoch:  5
# ### Fold 4 ###
# Best model found on epoch:  5
# Loading subject  6
# ### Fold 0 ###
# Best model found on epoch:  5
# ### Fold 1 ###
# Best model found on epoch:  49
# ### Fold 2 ###
# Best model found on epoch:  24
# ### Fold 3 ###
# Best model found on epoch:  5
# ### Fold 4 ###
# Best model found on epoch:  12
# Loading subject  7
# ### Fold 0 ###
# Best model found on epoch:  4
# ### Fold 1 ###
# Best model found on epoch:  5
# ### Fold 2 ###
# Best model found on epoch:  5
# ### Fold 3 ###
# Best model found on epoch:  5
# ### Fold 4 ###
# Best model found on epoch:  49
# Loading subject  8
# ### Fold 0 ###
# Best model found on epoch:  15
# ### Fold 1 ###
# Best model found on epoch:  42
# ### Fold 2 ###
# Best model found on epoch:  6
# ### Fold 3 ###
# Best model found on epoch:  19
# ### Fold 4 ###
# Best model found on epoch:  18
# Loading subject  9
# ### Fold 0 ###
# Best model found on epoch:  49
# ### Fold 1 ###
# Best model found on epoch:  33
# ### Fold 2 ###
# Best model found on epoch:  49
# ### Fold 3 ###
# Best model found on epoch:  13
# ### Fold 4 ###
# Best model found on epoch:  5
# Loading subject  10
# ### Fold 0 ###
# Best model found on epoch:  4
# ### Fold 1 ###
# Best model found on epoch:  49
# ### Fold 2 ###
# Best model found on epoch:  9
# ### Fold 3 ###
# Best model found on epoch:  5
# ### Fold 4 ###
# Best model found on epoch:  23
# ######## Dropout: 0.1
# Loading subject  1
# ### Fold 0 ###
# Best model found on epoch:  45
# ### Fold 1 ###
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jonlis/inner-speech-detection/EXdropout_deep.ipynb Cell 2' in <module>
#       <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000002vscode-remote?line=1'>2</a> saved_models1 = cross_validation_loop(dropout=0.01)
#       <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000002vscode-remote?line=2'>3</a> print("######## Dropout: 0.1")
# ----> <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000002vscode-remote?line=3'>4</a> saved_models2 = cross_validation_loop(dropout=0.1)
#
# /home/jonlis/inner-speech-detection/EXdropout_deep.ipynb Cell 1' in cross_validation_loop(LR, epochs, batch_size, dropout)
#      <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=57'>58</a> train_data, val_data, test_data, train_labels, val_labels, test_labels = to_device(train_data, val_data, test_data, train_labels, val_labels, test_labels, device)
#      <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=58'>59</a> # Train loop
# ---> <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=59'>60</a> train_model(model, train_data = train_data, train_labels = train_labels, val_data = val_data, val_labels = val_labels,
#      <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=60'>61</a>             epochs = epochs, batch_size = batch_size, loss_func = loss_func, optimizer = op)
#      <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=61'>62</a> # Save model
#      <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=62'>63</a> subject_models.append(model)
#
# File /tmp/ipykernel_8350/1775631849.py:33, in train_model(model, train_data, train_labels, val_data, val_labels, epochs, batch_size, loss_func, optimizer)
#      <a href='file:///tmp/ipykernel_8350/1775631849.py?line=29'>30</a> loss = loss_func(train_outputs, train_truth)
#      <a href='file:///tmp/ipykernel_8350/1775631849.py?line=31'>32</a> epoch_train_loss += loss
# ---> <a href='file:///tmp/ipykernel_8350/1775631849.py?line=32'>33</a> loss.backward()
#      <a href='file:///tmp/ipykernel_8350/1775631849.py?line=33'>34</a> optimizer.step()
#      <a href='file:///tmp/ipykernel_8350/1775631849.py?line=34'>35</a> optimizer.zero_grad()
#
# File ~/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/_tensor.py:307, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/_tensor.py?line=297'>298</a> if has_torch_function_unary(self):
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/_tensor.py?line=298'>299</a>     return handle_torch_function(
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/_tensor.py?line=299'>300</a>         Tensor.backward,
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/_tensor.py?line=300'>301</a>         (self,),
#    (...)
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/_tensor.py?line=304'>305</a>         create_graph=create_graph,
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/_tensor.py?line=305'>306</a>         inputs=inputs)
# --> <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/_tensor.py?line=306'>307</a> torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/autograd/__init__.py:154, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/autograd/__init__.py?line=150'>151</a> if retain_graph is None:
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/autograd/__init__.py?line=151'>152</a>     retain_graph = create_graph
# --> <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/autograd/__init__.py?line=153'>154</a> Variable._execution_engine.run_backward(
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/autograd/__init__.py?line=154'>155</a>     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/autograd/__init__.py?line=155'>156</a>     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
print("######## Dropout: 0.1")
saved_models2 = cross_validation_loop(dropout=0.1)

# %%
print("######## Dropout: 0.25")
saved_models3 = cross_validation_loop(dropout=0.25)
print("######## Dropout: 0.5")
saved_models4 = cross_validation_loop(dropout=0.5)
# Out:
# ######## Dropout: 0.01
# Loading subject  1
# ### Fold 0 ###
# Best model found on epoch:  5
# ### Fold 1 ###
# Best model found on epoch:  8
# ### Fold 2 ###
# Best model found on epoch:  8
# ### Fold 3 ###
# Best model found on epoch:  8
# ### Fold 4 ###
# Best model found on epoch:  49
# Loading subject  2
# ### Fold 0 ###
# Best model found on epoch:  28
# ### Fold 1 ###
# Best model found on epoch:  9
# ### Fold 2 ###
# Best model found on epoch:  5
# ### Fold 3 ###
# Best model found on epoch:  12
# ### Fold 4 ###
# Best model found on epoch:  5
# Loading subject  3
# ### Fold 0 ###
# Best model found on epoch:  49
# ### Fold 1 ###
# Best model found on epoch:  6
# ### Fold 2 ###
# Best model found on epoch:  30
# ### Fold 3 ###
# Best model found on epoch:  5
# ### Fold 4 ###
# Best model found on epoch:  49
# Loading subject  4
# ### Fold 0 ###
# Best model found on epoch:  46
# ### Fold 1 ###
# Best model found on epoch:  6
# ### Fold 2 ###
# Best model found on epoch:  21
# ### Fold 3 ###
# Best model found on epoch:  26
# ### Fold 4 ###
# Best model found on epoch:  18
# Loading subject  5
# ### Fold 0 ###
# Best model found on epoch:  45
# ### Fold 1 ###
# Best model found on epoch:  6
# ### Fold 2 ###
# Best model found on epoch:  12
# ### Fold 3 ###
# Best model found on epoch:  49
# ### Fold 4 ###
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jonlis/inner-speech-detection/EXdropout_deep.ipynb Cell 2' in <module>
#       <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000001vscode-remote?line=0'>1</a> print("######## Dropout: 0.01")
# ----> <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000001vscode-remote?line=1'>2</a> saved_models1 = cross_validation_loop(dropout=0.01)
#       <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000001vscode-remote?line=2'>3</a> print("######## Dropout: 0.1")
#       <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000001vscode-remote?line=3'>4</a> saved_models2 = cross_validation_loop(dropout=0.1)
#
# /home/jonlis/inner-speech-detection/EXdropout_deep.ipynb Cell 1' in cross_validation_loop(LR, epochs, batch_size, dropout)
#      <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=57'>58</a> train_data, val_data, test_data, train_labels, val_labels, test_labels = to_device(train_data, val_data, test_data, train_labels, val_labels, test_labels, device)
#      <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=58'>59</a> # Train loop
# ---> <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=59'>60</a> train_model(model, train_data = train_data, train_labels = train_labels, val_data = val_data, val_labels = val_labels,
#      <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=60'>61</a>             epochs = epochs, batch_size = batch_size, loss_func = loss_func, optimizer = op)
#      <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=61'>62</a> # Save model
#      <a href='vscode-notebook-cell://ssh-remote%2B109.225.89.145/home/jonlis/inner-speech-detection/EXdropout_deep.ipynb#ch0000000vscode-remote?line=62'>63</a> subject_models.append(model)
#
# File /tmp/ipykernel_78919/1775631849.py:34, in train_model(model, train_data, train_labels, val_data, val_labels, epochs, batch_size, loss_func, optimizer)
#      <a href='file:///tmp/ipykernel_78919/1775631849.py?line=31'>32</a>     epoch_train_loss += loss
#      <a href='file:///tmp/ipykernel_78919/1775631849.py?line=32'>33</a>     loss.backward()
# ---> <a href='file:///tmp/ipykernel_78919/1775631849.py?line=33'>34</a>     optimizer.step()
#      <a href='file:///tmp/ipykernel_78919/1775631849.py?line=34'>35</a>     optimizer.zero_grad()
#      <a href='file:///tmp/ipykernel_78919/1775631849.py?line=37'>38</a> model.eval() # Set model to evaluation mode
#
# File ~/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/optimizer.py:88, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#      <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/optimizer.py?line=85'>86</a> profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/optimizer.py?line=86'>87</a> with torch.autograd.profiler.record_function(profile_name):
# ---> <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/optimizer.py?line=87'>88</a>     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/autograd/grad_mode.py:28, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/autograd/grad_mode.py?line=24'>25</a> @functools.wraps(func)
#      <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/autograd/grad_mode.py?line=25'>26</a> def decorate_context(*args, **kwargs):
#      <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/autograd/grad_mode.py?line=26'>27</a>     with self.__class__():
# ---> <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/autograd/grad_mode.py?line=27'>28</a>         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py:133, in Adam.step(self, closure)
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=129'>130</a>             # record the step after step update
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=130'>131</a>             state_steps.append(state['step'])
# --> <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=132'>133</a>     F.adam(params_with_grad,
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=133'>134</a>            grads,
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=134'>135</a>            exp_avgs,
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=135'>136</a>            exp_avg_sqs,
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=136'>137</a>            max_exp_avg_sqs,
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=137'>138</a>            state_steps,
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=138'>139</a>            amsgrad=group['amsgrad'],
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=139'>140</a>            beta1=beta1,
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=140'>141</a>            beta2=beta2,
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=141'>142</a>            lr=group['lr'],
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=142'>143</a>            weight_decay=group['weight_decay'],
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=143'>144</a>            eps=group['eps'])
#     <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/adam.py?line=144'>145</a> return loss
#
# File ~/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/_functional.py:94, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/_functional.py?line=91'>92</a>     denom = (max_exp_avg_sqs[i].sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/_functional.py?line=92'>93</a> else:
# ---> <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/_functional.py?line=93'>94</a>     denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/_functional.py?line=95'>96</a> step_size = lr / bias_correction1
#      <a href='file:///home/jonlis/miniconda3/envs/inner_speech/lib/python3.8/site-packages/torch/optim/_functional.py?line=97'>98</a> param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:
